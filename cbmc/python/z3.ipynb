# %%
from z3 import *

# %%
solver = Solver()
solver.reset()

constraints = parse_smt2_file("/tmp/cbmc.smt2", sorts={}, decls={})
solver.add(constraints)

# %%
# Wrapper for allowing Z3 ASTs to be stored into Python Hashtables. 
class AstRefKey:
    def __init__(self, n):
        self.n = n
    def __hash__(self):
        return self.n.hash()
    def __eq__(self, other):
        return self.n.eq(other.n)
    def __repr__(self):
        return str(self.n)

def askey(n):
    assert isinstance(n, AstRef)
    return AstRefKey(n)

def get_vars(f):
    r = set()
    def collect(f):
      if is_const(f): 
          if f.decl().kind() == Z3_OP_UNINTERPRETED and not askey(f) in r:
              r.add(askey(f))
      else:
          for c in f.children():
              collect(c)
    collect(f)
    return {ele.n for ele in r}

def get_var_names(f):
    r = set()
    def collect(f):
      if is_const(f): 
          if f.decl().kind() == Z3_OP_UNINTERPRETED and not askey(f) in r:
              r.add(askey(f))
      else:
          for c in f.children():
              collect(c)
    collect(f)
    return {str(ele.n) for ele in r}

# %%
list_of_var_set = [get_var_names(a) for a in constraints]
list_of_vars = set().union(*list_of_var_set)
obsvs = [o for o in list_of_vars if "Observation_" in o]
obsvs.sort(key=lambda x: int(x.split("_")[-1].split("!")[0]))
len(obsvs)
# Out:
# 17

# %%
import re
# either a declaration, definition, lhs equality that contains var
# if none of the above, then any constraint that contains var
def is_important_constraint(constraint, var):
    if "__CPROVER_deallocated" in constraint and var in constraint:
        # we want to preserve safe-pointer constraint
        return True
    pattern = "(\(assert \(= |\(define-fun |\(declare-fun |\(assert \(= \(select )(\|.*?\|)"
    matches = re.match(pattern, constraint)
    if matches:
        if matches.group(2) == var:
            return True
        else:
            return False
    else:
        return var in constraint

[is_important_constraint("(declare-fun |Observation_2177| () (_ BitVec 32))", "|Observation_2177|"),
is_important_constraint("(define-fun |B4975| () Bool (=> |goto_symex::&92;guard#99| (not (= ((_ zero_extend 20) ((_ extract 31 20) (concat (_ bv205 12) (_ bv0 20)))) ((_ zero_extend 20) ((_ extract 31 20) |__CPROVER_deallocated#0|))))))", "|B4975|"),
is_important_constraint("(define-fun |B4975| () Bool (=> |goto_symex::&92;guard#99| (not (= ((_ zero_extend 20) ((_ extract 31 20) (concat (_ bv205 12) (_ bv0 20)))) ((_ zero_extend 20) ((_ extract 31 20) |__CPROVER_deallocated#0|))))))", "|goto_symex::&92;guard#99|"),
is_important_constraint("(assert (= |cbmc_pointer_offset_2375!0@1#2| (_ bv0 32)))", "|cbmc_pointer_offset_2375!0@1#2|"),
is_important_constraint("(assert (bvsge (bvmul |histogram::1::2::1::t!0@88#4| (_ bv4 32)) (_ bv0 32)))", "|histogram::1::2::1::t!0@88#4|"),
is_important_constraint("", "|histogram::1::2::1::t!0@88#4|"),
is_important_constraint("(assert (= |histogram::1::2::1::v!0@86#2| (select |main::1::a!0@1#1| (_ bv85 32))))", "|main::1::a!0@1#1|")]
# Out:
# [True, True, True, True, True, False, False]

# %%
import re

def get_var_in_constraint(constraints):
    pattern = "\|.*?\||array\.\\d*"
    matches = re.findall(pattern, constraints)
    return set(matches)



def get_constraints_for_var(file_path, var_name):
    f = open(file_path)
    lines = f.readlines()
    obsv_constraints = ""
    for line in lines:
        if var_name in line:
            obsv_constraints += line
    # pattern = "\|.*?\|"
    # matches = re.findall(pattern, obsv_constraints)
    # print(matches)
    
    # dependent_vars = set(filter(lambda m: var_name not in m, matches))
    dependent_vars = get_var_in_constraint(obsv_constraints)

    lines.reverse()
    first_line_of_obsv_constraint = "(declare-fun |Observation_0| () (_ BitVec 32))"
    active_searching = False
    cbmc_constraint = ""
    for line in lines:
        if first_line_of_obsv_constraint in line:
            active_searching = True
            continue
        if active_searching and any(map(lambda dep_var: is_important_constraint(line, dep_var), dependent_vars)):
            # HACK: assert the safe-point assertion
            pattern = "\(define-fun (\|B\d*\|)"
            matches = re.match(pattern, line)
            if matches and "__CPROVER_deallocated" in line:
                cbmc_constraint = "(assert {})\n".format(matches.group(1)) + cbmc_constraint

            dependent_vars = dependent_vars | get_var_in_constraint(line)
            dependent_vars.discard("|__CPROVER_deallocated#0|")
            cbmc_constraint = line + cbmc_constraint
    # print(dependent_vars)
    # print("----------------")
    # print(cbmc_constraint+obsv_constraints)
    # print("----------------")
    return parse_smt2_string("(declare-fun |__CPROVER_deallocated#0| () (_ BitVec 32))\n" + cbmc_constraint+obsv_constraints, sorts={}, decls={})
solver.reset()
print(*get_constraints_for_var("/tmp/cbmc.smt2", "|Observation_1336|"), sep="\n")

# %%
import time


def get_differential_set_for_obsv(obsv_name):
    solver = Solver()
    solver.reset()
    start_time = time.time()
    constraints = get_constraints_for_var("/tmp/cbmc.smt2", "|"+str(obsv_name)+"|")
    # constraints = parse_smt2_file("/tmp/cbmc.smt2", sorts={}, decls={})
    solver.add(constraints)

    obsv = None
    for a in solver.assertions():
        for v in get_vars(a):
            if str(v) == str(obsv_name):
                obsv = v
    assert(obsv != None)


    slicing_elapsed_time = round(time.time() - start_time, 2)
    all_models = []
    start_time = time.time()
    for i in range(1000):
        if (solver.check() == sat):
            m = solver.model()
            all_models.append(m[obsv].as_signed_long())
            solver.add(obsv != m[obsv])
        else:
            break
        
    elapsed_time = round(time.time() - start_time, 2)

    object_id_to_offsets = {}
    object_gap = 1048576
    for val in all_models:
        object_id = val // object_gap
        if object_id not in object_id_to_offsets:
            object_id_to_offsets[object_id] = []
        object_id_to_offsets[object_id].append(val % object_gap)
    print(obsv, slicing_elapsed_time, elapsed_time, len(constraints), len(all_models))
    return (elapsed_time, len(all_models), object_id_to_offsets)

infos = {o: get_differential_set_for_obsv(str(o)) for o in ["Observation_1"]}
# Out:
# Observation_1 0.01 0.03 3 1

# %%
from joblib import Parallel, delayed
def wrapper(o):
    return (o, get_differential_set_for_obsv(o))
tuple_list = Parallel(n_jobs=6)(delayed(wrapper)(str(o)) for o in obsvs)
infos = dict(tuple_list)
# Out:
# Observation_0 0.02 0.01 3 1
# Observation_2 0.01 0.03 5 2
# Observation_6 0.02 0.02 3 1
# Observation_7 0.02 0.02 3 1
# Observation_1 0.01 0.01 3 1
# Observation_3 0.02 0.01 5 2
# Observation_10Observation_8 0.02 0.01 3 1
#  0.01 0.01 3 1
# Observation_9 0.03 0.01 3 1
# Observation_11 0.01 0.01 3 1
# Observation_12Observation_14 0.01 0.02 3 1
# Observation_15 0.01 0.01 3 1
# Observation_13 0.01 0.03 3 1
#  0.02 0.01 3 1
# Observation_4 0.01 0.01 5 2
# Observation_16 0.01 0.01 3 1
# Observation_5 0.01 0.0 3 1

# %%
infos
# Out:
# {'Observation_0': (0.01, 1, {2: [0]}),
#  'Observation_1': (0.01, 1, {4: [0]}),
#  'Observation_2': (0.03, 2, {5: [0], -1: [1048575]}),
#  'Observation_3': (0.01, 2, {5: [0], -1: [1048575]}),
#  'Observation_4': (0.01, 2, {-1: [1048575], 2: [0]}),
#  'Observation_5': (0.0, 1, {7: [0]}),
#  'Observation_6': (0.02, 1, {8: [0]}),
#  'Observation_7': (0.02, 1, {9: [0]}),
#  'Observation_8': (0.01, 1, {10: [0]}),
#  'Observation_9': (0.01, 1, {10: [0]}),
#  'Observation_10': (0.01, 1, {9: [0]}),
#  'Observation_11': (0.01, 1, {8: [0]}),
#  'Observation_12': (0.01, 1, {9: [0]}),
#  'Observation_13': (0.03, 1, {10: [0]}),
#  'Observation_14': (0.02, 1, {10: [0]}),
#  'Observation_15': (0.01, 1, {9: [0]}),
#  'Observation_16': (0.01, 1, {11: [0]})}

# %%
def get_pointer_to_name_and_type_map():
    mapping = {}
    f = open("/tmp/pointer_numbering.csv")
    for line in f.readlines():
        line = line.strip()
        splits = line.split(",")
        var_type = splits[0]
        full_var = splits[1]
        numbering = splits[2]
        #histogram::1::2::i!0@1
        #histogram$$1$$2$$1$$i
        #histogram$$1$$2$$1$$1$$t
        mapping[int(numbering)] = (full_var.split("::")[-1].split("!")[0], var_type)
    return mapping

def is_pointer_or_array(var_type):
    # return "*" in var_type or var_type.count('[') >= 2
    return var_type.count('[') >= 2

pointer_mapping = get_pointer_to_name_and_type_map()
ds_file = open("/tmp/ds_of_obsvs.txt", "w")
for obsv, info in infos.items():
    index = str(obsv).split("_")[1]
    memory_locs = []
    ds_size = 0
    for (base, offsets) in info[2].items():
        if (base == -1):
            # decoy access is not part of ds
            continue
        var_name = pointer_mapping[base][0]
        var_type = pointer_mapping[base][1]
        for offset in offsets:
            memory_locs.append("((char*){}{})+{}".format("" if is_pointer_or_array(var_type) else "&", var_name, offset))
            ds_size += 1
    memory_locs = ",".join(memory_locs)
    memory_locs = "{"+memory_locs+"}"
    ds_file.write("#define ds_{} (void* [{}]){}\n".format(index, ds_size, memory_locs))
    ds_file.write("#define ds_size_{} {}\n".format(index, ds_size))
ds_file.close()

# %%
start_time = time.time()
solver.check()
elapsed_time = time.time() - start_time
print("TIME: " + str(elapsed_time))
# Out:
# TIME: 108.817866563797

# %%
bv_solver = Then(With('simplify', mul2concat=True),
                 'solve-eqs', 
                 'bit-blast', 
                 'aig',
                 'sat').solver()
start_time = time.time()
solve_using(bv_solver, solver.assertions())
elapsed_time = time.time() - start_time
print("TIME: " + str(elapsed_time))
# Out:
# failed to solve
# [array.3 = K(BitVec(32), 0),
#  array.2 = K(BitVec(32), 0),
#  array.1 = K(BitVec(32), 0),
#  array.4 = K(BitVec(32), 0),
#  array.0 = K(BitVec(32), 0),
#  main::1::key!0@1#1[[C]] = 0,
#  main::1::key!0@1#1[[7]] = 0,
#  main::1::key!0@1#1[[E]] = 0,
#  main::1::key!0@1#1[[F]] = 0,
#  main::1::key!0@1#1[[2]] = 0,
#  main::1::key!0@1#1[[4]] = 0,
#  main::1::key!0@1#1[[8]] = 0,
#  main::1::key!0@1#1[[0]] = 0,
#  main::1::key!0@1#1[[D]] = 0,
#  main::1::key!0@1#1[[5]] = 0,
#  main::1::key!0@1#1[[3]] = 0,
#  main::1::key!0@1#1[[1]] = 0,
#  main::1::key!0@1#1[[B]] = 0,
#  main::1::key!0@1#1[[9]] = 0,
#  main::1::key!0@1#1[[A]] = 0,
#  main::1::key!0@1#1[[6]] = 0,
#  Observation_1359 = 76800,
#  Observation_1358 = 16399,
#  Observation_1357 = 15360,
#  Observation_1356 = 24576,
#  Observation_1355 = 16398,
#  Observation_1354 = 15360,
#  Observation_1353 = 24576,
#  Observation_1352 = 16397,
#  Observation_1351 = 15360,
#  Observation_1350 = 24576,
#  Observation_1349 = 16396,
#  Observation_1348 = 15360,
#  Observation_1347 = 24576,
#  Observation_1346 = 16395,
#  Observation_1345 = 15360,
#  Observation_1344 = 22528,
#  Observation_1343 = 16394,
#  Observation_1342 = 15360,
#  Observation_1341 = 22528,
#  Observation_1340 = 16393,
#  Observation_1339 = 15360,
#  Observation_1338 = 22528,
#  Observation_1337 = 16392,
#  Observation_1336 = 15360,
#  Observation_1335 = 22528,
#  Observation_1334 = 16391,
#  Observation_1333 = 15360,
#  Observation_1332 = 20480,
#  Observation_1331 = 16390,
#  Observation_1330 = 15360,
#  Observation_1329 = 20480,
#  Observation_1328 = 16389,
#  Observation_1327 = 15360,
#  Observation_1326 = 20480,
#  Observation_1325 = 16388,
#  Observation_1324 = 15360,
#  Observation_1323 = 20480,
#  Observation_1322 = 16387,
#  Observation_1321 = 15360,
#  Observation_1320 = 18432,
#  Observation_1319 = 16386,
#  Observation_1318 = 15360,
#  Observation_1317 = 18432,
#  Observation_1316 = 16385,
#  Observation_1315 = 15360,
#  Observation_1314 = 18432,
#  Observation_1313 = 16384,
#  Observation_1312 = 15360,
#  Observation_1311 = 18432,
#  Observation_1310 = 24576,
#  Observation_1309 = 11264,
#  Observation_1308 = 36864,
#  Observation_1307 = 11264,
#  Observation_1306 = 34816,
#  Observation_1305 = 11264,
#  Observation_1304 = 32768,
#  Observation_1303 = 11274,
#  Observation_1302 = 38912,
#  Observation_1301 = 4276,
#  Observation_1300 = 75776,
#  Observation_1299 = 17408,
#  Observation_1298 = 17408,
#  Observation_1297 = 75776,
#  Observation_1296 = 17408,
#  Observation_1295 = 22528,
#  Observation_1294 = 11264,
#  Observation_1293 = 34816,
#  Observation_1292 = 11264,
#  Observation_1291 = 32768,
#  Observation_1290 = 11264,
#  Observation_1289 = 38912,
#  Observation_1288 = 11394,
#  Observation_1287 = 36864,
#  Observation_1286 = 4272,
#  Observation_1285 = 74752,
#  Observation_1284 = 17408,
#  Observation_1283 = 17408,
#  Observation_1282 = 74752,
#  Observation_1281 = 17408,
#  Observation_1280 = 20480,
#  Observation_1279 = 11264,
#  Observation_1278 = 32768,
#  Observation_1277 = 11264,
#  Observation_1276 = 38912,
#  Observation_1275 = 11264,
#  Observation_1274 = 36864,
#  Observation_1273 = 11342,
#  Observation_1272 = 34816,
#  Observation_1271 = 4268,
#  Observation_1270 = 73728,
#  Observation_1269 = 17408,
#  Observation_1268 = 17408,
#  Observation_1267 = 73728,
#  Observation_1266 = 17408,
#  Observation_1265 = 18432,
#  Observation_1264 = 11264,
#  Observation_1263 = 38912,
#  Observation_1262 = 11264,
#  Observation_1261 = 36864,
#  Observation_1260 = 11264,
#  Observation_1259 = 34816,
#  Observation_1258 = 11492,
#  Observation_1257 = 32768,
#  Observation_1256 = 4264,
#  Observation_1255 = 72704,
#  Observation_1254 = 17408,
#  Observation_1253 = 17408,
#  Observation_1252 = 72704,
#  ...]
# TIME: 303.93798661231995

# %%
len(solver.assertions())
# Out:
# 7873

# %%
print([obsv != m[obsv] for obsv in obsvs][:10])
# Out:
# [2048 != Observation_0, 3072 != Observation_1, 5120 != Observation_2, 7168 != Observation_3, 7168 != Observation_4, 3072 != Observation_5, 4096 != Observation_6, 8192 != Observation_9, 8192 != Observation_10, 3072 != Observation_11]

# %%
t = Then('simplify', 'bit-blast', 'tseitin-cnf')
g = Goal()

a, b = BitVecs('a b', 8)

g.add(Or(a == 1, a == 0))
g.add(Implies(a == 0, And(0 <= b, b < 8)))
bitmap = {}
for ob in [a,b]:
    for i in range(ob.size()):
        bitmap[(ob, i)] = Bool(str(ob)+str(i))
        mask = BitVecSort(ob.size()).cast(math.pow(2, i))
        g.add(bitmap[(ob, i)] == ((ob & mask) == mask))
sg = t(g)

# %%
x, y = BitVecs('x y', 10)
s = Solver()
s.add(x > 0, y > 0, x + y == 512)
s.check()
# Out:
# sat

# %%
with open("/tmp/tmp.smt2", mode='w') as f:
    f.write(s.to_smt2())

# %%
list_of_var_set = [get_vars(a) for a in g]
list_of_vars = set().union(*list_of_var_set)


goal = sg[0]
var_set, var_map = var_set_and_map(goal)
cnf_str = "p cnf {} {}\n".format(len(var_set), len(goal))

sampling_set = []
for ob in [a,b]:
    for i in range(ob.size()):
        sampling_set.append(var_map[bitmap[(ob, i)]])
cnf_str += "c ind {} 0\n".format(" ".join(sampling_set))


for i in range(len(goal)):
    if (is_or(goal[i])):
        for j in range(goal[i].num_args()):
            assert(goal[i].arg(j).num_args() <= 1)
            lit = goal[i].arg(j)
            if is_not(lit):
                cnf_str += "-" + var_map[lit.arg(0)]
            else:
                cnf_str += var_map[lit]
            cnf_str += " "
    else:
        # this clause is just a literal
        assert(goal[i].num_args() <= 1)
        lit = goal[i]
        if is_not(lit):
            cnf_str += "-" + var_map[lit.arg(0)]
        else:
            cnf_str += var_map[lit]
        cnf_str += " "
    cnf_str += "0\n"
    
with open("/home/cream/toy/cnf.dimacs", "w") as f:
    f.write(cnf_str)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1991387/3845753712.py in <module>
# ----> 1 list_of_var_set = [get_vars(a) for a in g]
#       2 list_of_vars = set().union(*list_of_var_set)
#       3
#       4
#       5 goal = sg[0]
#
# NameError: name 'g' is not defined

# %%
# count num of variables
def var_set_and_map(goal):    
    list_of_var_set = [get_vars(a) for a in goal]
    var_set = set().union(*list_of_var_set)

    # give each variable a name
    var_map = {}
    for i, v in enumerate(var_set):
        var_map[v] = str(i+1)

    return var_set, var_map

def generate_cnf(goal, obs):
    var_set, var_map = var_set_and_map(goal)
    cnf_str = "p cnf {} {}\n".format(len(var_set), len(goal))
    
    # gather sampling set(bits of the interested values)
    sampling_set = []
    for ob in obs:
        for i in range(ob.size()):
            sampling_set.append(var_map[bitmap[(ob, i)]])
    cnf_str += "c ind {} 0\n".format(" ".join(sampling_set))


    for i in range(len(goal)):
        if (is_or(goal[i])):
            for j in range(goal[i].num_args()):
                assert(goal[i].arg(j).num_args() <= 1)
                lit = goal[i].arg(j)
                if is_not(lit):
                    cnf_str += "-" + var_map[lit.arg(0)]
                else:
                    cnf_str += var_map[lit]
                cnf_str += " "
        else:
            print(goal[i])
            # this clause is just a literal
            assert(goal[i].num_args() <= 1)
            lit = goal[i]
            if is_not(lit):
                cnf_str += "-" + var_map[lit.arg(0)]
            else:
                cnf_str += var_map[lit]
            cnf_str += " "
        cnf_str += "0\n"
    return cnf_str

# %%
with open("/home/cream/play/cnf", "w") as f:
    f.write(cnf_str)

# %%
t = Then('simplify', 'bit-blast', 'tseitin-cnf')
g = Goal()

F = BitVecVal(0, 2)
T = BitVecVal(1, 2)
N = BitVecVal(2, 2)

o0, o1 = BitVecs('o0 o1', 2)
A, B, k, p, o2, o3, o4 = BitVecs('A B k p o2 o3 o4', 32) # bitvectors are signed, so use 4 instead 3 to hold a maximum value of 8

obs = [o0, o2, o3]

# secret value
g.add(0 <= k, k <= 2**3)
# public value
g.add(p == 0)
# memory allocation
g.add(A == 0, B == 0)

g.add(o0 == If(k < 4, T, F))
g.add(o1 == If(k < 4, If(k < 2, T, F), N))
g.add(o2 == If(k < 4, If(k < 2, B + p, B + p), B + p))
g.add(o3 == If(k < 4, If(k < 2, A + k / 3, A + k % 2), A + k / 4))


g.add(o0 == If(k < 4, T, F))
g.add(o2 == If(k < 4, A + k % 2, A + k /2))
g.add(o3 == B + k / 5)

obs = [o0, o2, o3, o4]
g.add(o0 == If(k < 2**19, T, N))
g.add(o2 == If(k < 2**19, A + k % 2, A + k /2))
g.add(o3 == If(k < 2**19, A + p, 2**20+1))
g.add(o4 == B + k / 5)


bitmap = {}
for ob in obs:
    for i in range(ob.size()):
        bitmap[(ob, i)] = Bool(str(ob)+str(i))
        mask = BitVecSort(ob.size()).cast(math.pow(2, i))
        g.add(bitmap[(ob, i)] == ((ob & mask) == mask))

sg = t(g)
print(g)

# %%
x = Int('x')
y = Int('y')
f = Function('f', IntSort(), IntSort())
s = Solver()
s.add(f(f(x)) == x, f(x) == y, x != y)
print(s.check())
m = s.model()
print(m)
print("f(f(x)) =", m.evaluate(f(f(x))))
print("f(x)    =", m.evaluate(f(x)))

# %%
solver = z3.Solver()
solver.reset()

constraints = z3.parse_smt2_file("/home/cream/src/smtapproxmc/temp_amc/temp_0_0.smt2", sorts={}, decls={})
solver.add(constraints)
solver.check()

# remove variables from CPROVER initializer
constraints = list(filter(lambda c: not(is_eq(c) and str(c.arg(0)).startswith("__CPROVER")), constraints))
print("\n------\n".join([str(c) for c in constraints]))
# Out:
# array.0[0] == 99
# ------
# array.0[1] == 124
# ------
# array.0[2] == 119
# ------
# array.0[3] == 123
# ------
# array.0[4] == 242
# ------
# array.0[5] == 107
# ------
# array.0[6] == 111
# ------
# array.0[7] == 197
# ------
# array.0[8] == 48
# ------
# array.0[9] == 1
# ------
# array.0[10] == 103
# ------
# array.0[11] == 43
# ------
# array.0[12] == 254
# ------
# array.0[13] == 215
# ------
# array.0[14] == 171
# ------
# array.0[15] == 118
# ------
# array.0[16] == 202
# ------
# array.0[17] == 130
# ------
# array.0[18] == 201
# ------
# array.0[19] == 125
# ------
# array.0[20] == 250
# ------
# array.0[21] == 89
# ------
# array.0[22] == 71
# ------
# array.0[23] == 240
# ------
# array.0[24] == 173
# ------
# array.0[25] == 212
# ------
# array.0[26] == 162
# ------
# array.0[27] == 175
# ------
# array.0[28] == 156
# ------
# array.0[29] == 164
# ------
# array.0[30] == 114
# ------
# array.0[31] == 192
# ------
# array.0[32] == 183
# ------
# array.0[33] == 253
# ------
# array.0[34] == 147
# ------
# array.0[35] == 38
# ------
# array.0[36] == 54
# ------
# array.0[37] == 63
# ------
# array.0[38] == 247
# ------
# array.0[39] == 204
# ------
# array.0[40] == 52
# ------
# array.0[41] == 165
# ------
# array.0[42] == 229
# ------
# array.0[43] == 241
# ------
# array.0[44] == 113
# ------
# array.0[45] == 216
# ------
# array.0[46] == 49
# ------
# array.0[47] == 21
# ------
# array.0[48] == 4
# ------
# array.0[49] == 199
# ------
# array.0[50] == 35
# ------
# array.0[51] == 195
# ------
# array.0[52] == 24
# ------
# array.0[53] == 150
# ------
# array.0[54] == 5
# ------
# array.0[55] == 154
# ------
# array.0[56] == 7
# ------
# array.0[57] == 18
# ------
# array.0[58] == 128
# ------
# array.0[59] == 226
# ------
# array.0[60] == 235
# ------
# array.0[61] == 39
# ------
# array.0[62] == 178
# ------
# array.0[63] == 117
# ------
# array.0[64] == 9
# ------
# array.0[65] == 131
# ------
# array.0[66] == 44
# ------
# array.0[67] == 26
# ------
# array.0[68] == 27
# ------
# array.0[69] == 110
# ------
# array.0[70] == 90
# ------
# array.0[71] == 160
# ------
# array.0[72] == 82
# ------
# array.0[73] == 59
# ------
# array.0[74] == 214
# ------
# array.0[75] == 179
# ------
# array.0[76] == 41
# ------
# array.0[77] == 227
# ------
# array.0[78] == 47
# ------
# array.0[79] == 132
# ------
# array.0[80] == 83
# ------
# array.0[81] == 209
# ------
# array.0[82] == 0
# ------
# array.0[83] == 237
# ------
# array.0[84] == 32
# ------
# array.0[85] == 252
# ------
# array.0[86] == 177
# ------
# array.0[87] == 91
# ------
# array.0[88] == 106
# ------
# array.0[89] == 203
# ------
# array.0[90] == 190
# ------
# array.0[91] == 57
# ------
# array.0[92] == 74
# ------
# array.0[93] == 76
# ------
# Implies(Not(True), Observation_957 == 4294967295)
# ------
# Implies(Not(True), Observation_958 == 4294967295)
# ------
# Implies(Not(True), Observation_959 == 4294967295)
# ------
# Implies(Not(True), Observation_960 == 4294967295)
# ------
# Implies(Not(True), Observation_961 == 4294967295)
# ------
# Implies(Not(True), Observation_962 == 4294967295)
# ------
# Implies(Not(True), Observation_963 == 4294967295)
# ------
# Implies(Not(True), Observation_964 == 4294967295)
# ------
# Implies(Not(True), Observation_965 == 4294967295)
# ------
# Implies(Not(True), Observation_966 == 4294967295)
# ------
# Implies(Not(True), Observation_967 == 4294967295)
# ------
# Implies(Not(True), Observation_968 == 4294967295)
# ------
# Implies(Not(True), Observation_969 == 4294967295)
# ------
# Implies(Not(True), Observation_970 == 4294967295)
# ------
# Implies(Not(True), Observation_971 == 4294967295)
# ------
# Implies(Not(True), Observation_972 == 4294967295)
# ------
# Implies(Not(True), Observation_973 == 4294967295)
# ------
# Implies(Not(True), Observation_974 == 4294967295)
# ------
# Implies(Not(True), Observation_975 == 4294967295)
# ------
# Implies(Not(True), Observation_976 == 4294967295)
# ------
# Implies(Not(True), Observation_977 == 4294967295)
# ------
# Implies(Not(True), Observation_978 == 4294967295)
# ------
# Implies(Not(True), Observation_979 == 4294967295)
# ------
# Implies(Not(True), Observation_980 == 4294967295)
# ------
# Implies(Not(True), Observation_981 == 4294967295)
# ------
# Implies(Not(True), Observation_982 == 4294967295)
# ------
# Implies(Not(True), Observation_983 == 4294967295)
# ------
# Implies(Not(True), Observation_984 == 4294967295)
# ------
# Implies(Not(True), Observation_985 == 4294967295)
# ------
# Implies(Not(True), Observation_986 == 4294967295)
# ------
# Implies(Not(True), Observation_987 == 4294967295)
# ------
# Implies(Not(True), Observation_988 == 4294967295)
# ------
# Implies(Not(True), Observation_989 == 4294967295)
# ------
# Implies(Not(True), Observation_990 == 4294967295)
# ------
# Implies(Not(True), Observation_991 == 4294967295)
# ------
# Implies(Not(True), Observation_992 == 4294967295)
# ------
# Implies(Not(True), Observation_993 == 4294967295)
# ------
# Implies(Not(True), Observation_994 == 4294967295)
# ------
# Implies(Not(True), Observation_995 == 4294967295)
# ------
# Implies(Not(True), Observation_996 == 4294967295)
# ------
# Implies(Not(True), Observation_997 == 4294967295)
# ------
# Implies(Not(True), Observation_998 == 4294967295)
# ------
# Implies(Not(True), Observation_999 == 4294967295)
# ------
# Implies(Not(True), Observation_1000 == 4294967295)
# ------
# Implies(Not(True), Observation_1001 == 4294967295)
# ------
# Implies(Not(True), Observation_1002 == 4294967295)
# ------
# Implies(Not(True), Observation_1003 == 4294967295)
# ------
# Implies(Not(True), Observation_1004 == 4294967295)
# ------
# Implies(Not(True), Observation_1005 == 4294967295)
# ------
# Implies(Not(True), Observation_1006 == 4294967295)
# ------
# Implies(Not(True), Observation_1007 == 4294967295)
# ------
# Implies(Not(True), Observation_1008 == 4294967295)
# ------
# Implies(Not(True), Observation_1009 == 4294967295)
# ------
# Implies(Not(True), Observation_1010 == 4294967295)
# ------
# Implies(Not(True), Observation_1011 == 4294967295)
# ------
# Implies(Not(True), Observation_1012 == 4294967295)
# ------
# Implies(Not(True), Observation_1013 == 4294967295)
# ------
# Implies(Not(True), Observation_1014 == 4294967295)
# ------
# Implies(Not(True), Observation_1015 == 4294967295)
# ------
# Implies(Not(True), Observation_1016 == 4294967295)
# ------
# Implies(Not(True), Observation_1017 == 4294967295)
# ------
# Implies(Not(True), Observation_1018 == 4294967295)
# ------
# Implies(Not(True), Observation_1019 == 4294967295)
# ------
# Implies(Not(True), Observation_1020 == 4294967295)
# ------
# Implies(Not(True), Observation_1021 == 4294967295)
# ------
# Implies(Not(True), Observation_1022 == 4294967295)
# ------
# Implies(Not(True), Observation_1023 == 4294967295)
# ------
# Implies(Not(True), Observation_1024 == 4294967295)
# ------
# Implies(Not(True), Observation_1025 == 4294967295)
# ------
# Implies(Not(True), Observation_1026 == 4294967295)
# ------
# Implies(Not(True), Observation_1027 == 4294967295)
# ------
# Implies(Not(True), Observation_1028 == 4294967295)
# ------
# Implies(Not(True), Observation_1029 == 4294967295)
# ------
# Implies(Not(True), Observation_1030 == 4294967295)
# ------
# Implies(Not(True), Observation_1031 == 4294967295)
# ------
# Implies(Not(True), Observation_1032 == 4294967295)
# ------
# Implies(Not(True), Observation_1033 == 4294967295)
# ------
# Implies(Not(True), Observation_1034 == 4294967295)
# ------
# Implies(Not(True), Observation_1035 == 4294967295)
# ------
# Implies(Not(True), Observation_1036 == 4294967295)
# ------
# Implies(Not(True), Observation_1037 == 4294967295)
# ------
# Implies(Not(True), Observation_1038 == 4294967295)
# ------
# Implies(Not(True), Observation_1039 == 4294967295)
# ------
# Implies(Not(True), Observation_1040 == 4294967295)
# ------
# Implies(Not(True), Observation_1041 == 4294967295)
# ------
# Implies(Not(True), Observation_1042 == 4294967295)
# ------
# Implies(Not(True), Observation_1043 == 4294967295)
# ------
# Implies(Not(True), Observation_1044 == 4294967295)
# ------
# Implies(Not(True), Observation_1045 == 4294967295)
# ------
# Implies(Not(True), Observation_1046 == 4294967295)
# ------
# Implies(Not(True), Observation_1047 == 4294967295)
# ------
# Implies(Not(True), Observation_1048 == 4294967295)
# ------
# Implies(Not(True), Observation_1049 == 4294967295)
# ------
# Implies(Not(True), Observation_1050 == 4294967295)
# ------
# Implies(Not(True), Observation_1051 == 4294967295)
# ------
# Implies(Not(True), Observation_1052 == 4294967295)
# ------
# Implies(Not(True), Observation_1053 == 4294967295)
# ------
# Implies(Not(True), Observation_1054 == 4294967295)
# ------
# Implies(Not(True), Observation_1055 == 4294967295)
# ------
# Implies(Not(True), Observation_1056 == 4294967295)
# ------
# Implies(Not(True), Observation_1057 == 4294967295)
# ------
# Implies(Not(True), Observation_1058 == 4294967295)
# ------
# Implies(Not(True), Observation_1059 == 4294967295)
# ------
# Implies(Not(True), Observation_1060 == 4294967295)
# ------
# Implies(Not(True), Observation_1061 == 4294967295)
# ------
# Implies(Not(True), Observation_1062 == 4294967295)
# ------
# Implies(Not(True), Observation_1063 == 4294967295)
# ------
# Implies(Not(True), Observation_1064 == 4294967295)
# ------
# Implies(Not(True), Observation_1065 == 4294967295)
# ------
# Implies(Not(True), Observation_1066 == 4294967295)
# ------
# Implies(Not(True), Observation_1067 == 4294967295)
# ------
# Implies(Not(True), Observation_1068 == 4294967295)
# ------
# Implies(Not(True), Observation_1069 == 4294967295)
# ------
# Implies(Not(True), Observation_1070 == 4294967295)
# ------
# Implies(Not(True), Observation_1071 == 4294967295)
# ------
# Implies(Not(True), Observation_1072 == 4294967295)
# ------
# Implies(Not(True), Observation_1073 == 4294967295)
# ------
# Implies(Not(True), Observation_1074 == 4294967295)
# ------
# Implies(Not(True), Observation_1075 == 4294967295)
# ------
# Implies(Not(True), Observation_1076 == 4294967295)
# ------
# Implies(Not(True), Observation_1077 == 4294967295)
# ------
# Implies(Not(True), Observation_1078 == 4294967295)
# ------
# Implies(Not(True), Observation_1079 == 4294967295)
# ------
# Implies(Not(True), Observation_1080 == 4294967295)
# ------
# Implies(Not(True), Observation_1081 == 4294967295)
# ------
# Implies(Not(True), Observation_1082 == 4294967295)
# ------
# Implies(Not(True), Observation_1083 == 4294967295)
# ------
# Implies(Not(True), Observation_1084 == 4294967295)
# ------
# Implies(Not(True), Observation_1085 == 4294967295)
# ------
# Implies(Not(True), Observation_1086 == 4294967295)
# ------
# Implies(Not(True), Observation_1087 == 4294967295)
# ------
# Implies(Not(True), Observation_1088 == 4294967295)
# ------
# Implies(Not(True), Observation_1089 == 4294967295)
# ------
# Implies(Not(True), Observation_1090 == 4294967295)
# ------
# Implies(Not(True), Observation_1091 == 4294967295)
# ------
# Implies(Not(True), Observation_1092 == 4294967295)
# ------
# Implies(Not(True), Observation_1093 == 4294967295)
# ------
# Implies(Not(True), Observation_1094 == 4294967295)
# ------
# Implies(Not(True), Observation_1095 == 4294967295)
# ------
# Implies(Not(True), Observation_1096 == 4294967295)
# ------
# Implies(Not(True), Observation_1097 == 4294967295)
# ------
# Implies(Not(True), Observation_1098 == 4294967295)
# ------
# Implies(Not(True), Observation_1099 == 4294967295)
# ------
# Implies(Not(True), Observation_1100 == 4294967295)
# ------
# Implies(Not(True), Observation_1101 == 4294967295)
# ------
# Implies(Not(True), Observation_1102 == 4294967295)
# ------
# Implies(Not(True), Observation_1103 == 4294967295)
# ------
# Implies(Not(True), Observation_1104 == 4294967295)
# ------
# Implies(Not(True), Observation_1105 == 4294967295)
# ------
# Implies(Not(True), Observation_1106 == 4294967295)
# ------
# Implies(Not(True), Observation_1107 == 4294967295)
# ------
# Implies(Not(True), Observation_1108 == 4294967295)
# ------
# Implies(Not(True), Observation_1109 == 4294967295)
# ------
# Implies(Not(True), Observation_1110 == 4294967295)
# ------
# Implies(Not(True), Observation_1111 == 4294967295)
# ------
# Implies(Not(True), Observation_1112 == 4294967295)
# ------
# Implies(Not(True), Observation_1113 == 4294967295)
# ------
# Implies(Not(True), Observation_1114 == 4294967295)
# ------
# Implies(Not(True), Observation_1115 == 4294967295)
# ------
# Implies(Not(True), Observation_1116 == 4294967295)
# ------
# Implies(Not(True), Observation_1117 == 4294967295)
# ------
# Implies(Not(True), Observation_1118 == 4294967295)
# ------
# Implies(Not(True), Observation_1119 == 4294967295)
# ------
# Implies(Not(True), Observation_1120 == 4294967295)
# ------
# Implies(Not(True), Observation_1121 == 4294967295)
# ------
# Implies(Not(True), Observation_1122 == 4294967295)
# ------
# Implies(Not(True), Observation_1123 == 4294967295)
# ------
# Implies(Not(True), Observation_1124 == 4294967295)
# ------
# Implies(Not(True), Observation_1125 == 4294967295)
# ------
# Implies(Not(True), Observation_1126 == 4294967295)
# ------
# Implies(Not(True), Observation_1127 == 4294967295)
# ------
# Implies(Not(True), Observation_1128 == 4294967295)
# ------
# Implies(Not(True), Observation_1129 == 4294967295)
# ------
# Implies(Not(True), Observation_1130 == 4294967295)
# ------
# Implies(Not(True), Observation_1131 == 4294967295)
# ------
# Implies(Not(True), Observation_1132 == 4294967295)
# ------
# Implies(Not(True), Observation_1133 == 4294967295)
# ------
# Implies(Not(True), Observation_1134 == 4294967295)
# ------
# Implies(Not(True), Observation_1135 == 4294967295)
# ------
# Implies(Not(True), Observation_1136 == 4294967295)
# ------
# Implies(Not(True), Observation_1137 == 4294967295)
# ------
# Implies(Not(True), Observation_1138 == 4294967295)
# ------
# Implies(Not(True), Observation_1139 == 4294967295)
# ------
# Implies(Not(True), Observation_1140 == 4294967295)
# ------
# Implies(Not(True), Observation_1141 == 4294967295)
# ------
# Implies(Not(True), Observation_1142 == 4294967295)
# ------
# Implies(Not(True), Observation_1143 == 4294967295)
# ------
# Implies(Not(True), Observation_1144 == 4294967295)
# ------
# Implies(Not(True), Observation_1145 == 4294967295)
# ------
# Implies(Not(True), Observation_1146 == 4294967295)
# ------
# Implies(Not(True), Observation_1147 == 4294967295)
# ------
# Implies(Not(True), Observation_1148 == 4294967295)
# ------
# Implies(Not(True), Observation_1149 == 4294967295)
# ------
# Implies(Not(True), Observation_1150 == 4294967295)
# ------
# Implies(Not(True), Observation_1151 == 4294967295)
# ------
# Implies(Not(True), Observation_1152 == 4294967295)
# ------
# Implies(Not(True), Observation_1153 == 4294967295)
# ------
# Implies(Not(True), Observation_1154 == 4294967295)
# ------
# Implies(Not(True), Observation_1155 == 4294967295)
# ------
# Implies(Not(True), Observation_1156 == 4294967295)
# ------
# Implies(Not(True), Observation_1157 == 4294967295)
# ------
# Implies(Not(True), Observation_1158 == 4294967295)
# ------
# Implies(Not(True), Observation_1159 == 4294967295)
# ------
# Implies(Not(True), Observation_1160 == 4294967295)
# ------
# Implies(Not(True), Observation_1161 == 4294967295)
# ------
# Implies(Not(True), Observation_1162 == 4294967295)
# ------
# Implies(Not(True), Observation_1163 == 4294967295)
# ------
# Implies(Not(True), Observation_1164 == 4294967295)
# ------
# Implies(Not(True), Observation_1165 == 4294967295)
# ------
# Implies(Not(True), Observation_1166 == 4294967295)
# ------
# Implies(Not(True), Observation_1167 == 4294967295)
# ------
# Implies(Not(True), Observation_1168 == 4294967295)
# ------
# Implies(Not(True), Observation_1169 == 4294967295)
# ------
# Implies(Not(True), Observation_1170 == 4294967295)
# ------
# Implies(Not(True), Observation_1171 == 4294967295)
# ------
# Implies(Not(True), Observation_1172 == 4294967295)
# ------
# Implies(Not(True), Observation_1173 == 4294967295)
# ------
# Implies(Not(True), Observation_1174 == 4294967295)
# ------
# Implies(Not(True), Observation_1175 == 4294967295)
# ------
# Implies(Not(True), Observation_1176 == 4294967295)
# ------
# Implies(Not(True), Observation_1177 == 4294967295)
# ------
# Implies(Not(True), Observation_1178 == 4294967295)
# ------
# Implies(Not(True), Observation_1179 == 4294967295)
# ------
# Implies(Not(True), Observation_1180 == 4294967295)
# ------
# Implies(Not(True), Observation_1181 == 4294967295)
# ------
# Implies(Not(True), Observation_1182 == 4294967295)
# ------
# Implies(Not(True), Observation_1183 == 4294967295)
# ------
# Implies(Not(True), Observation_1184 == 4294967295)
# ------
# Implies(Not(True), Observation_1185 == 4294967295)
# ------
# Implies(Not(True), Observation_1186 == 4294967295)
# ------
# Implies(Not(True), Observation_1187 == 4294967295)
# ------
# Implies(Not(True), Observation_1188 == 4294967295)
# ------
# Implies(Not(True), Observation_1189 == 4294967295)
# ------
# Implies(Not(True), Observation_1190 == 4294967295)
# ------
# Implies(Not(True), Observation_1191 == 4294967295)
# ------
# Implies(Not(True), Observation_1192 == 4294967295)
# ------
# Implies(Not(True), Observation_1193 == 4294967295)
# ------
# Implies(Not(True), Observation_1194 == 4294967295)
# ------
# Implies(Not(True), Observation_1195 == 4294967295)
# ------
# Implies(Not(True), Observation_1196 == 4294967295)
# ------
# Implies(Not(True), Observation_1197 == 4294967295)
# ------
# Implies(Not(True), Observation_1198 == 4294967295)
# ------
# Implies(Not(True), Observation_1199 == 4294967295)
# ------
# Implies(Not(True), Observation_1200 == 4294967295)
# ------
# Implies(Not(True), Observation_1201 == 4294967295)
# ------
# Implies(Not(True), Observation_1202 == 4294967295)
# ------
# Implies(Not(True), Observation_1203 == 4294967295)
# ------
# Implies(Not(True), Observation_1204 == 4294967295)
# ------
# Implies(Not(True), Observation_1205 == 4294967295)
# ------
# Implies(Not(True), Observation_1206 == 4294967295)
# ------
# Implies(Not(True), Observation_1207 == 4294967295)
# ------
# Implies(Not(True), Observation_1208 == 4294967295)
# ------
# Implies(Not(True), Observation_1209 == 4294967295)
# ------
# Implies(Not(True), Observation_1210 == 4294967295)
# ------
# Implies(Not(True), Observation_1211 == 4294967295)
# ------
# Implies(Not(True), Observation_1212 == 4294967295)
# ------
# Implies(Not(True), Observation_1213 == 4294967295)
# ------
# Implies(Not(True), Observation_1214 == 4294967295)
# ------
# Implies(Not(True), Observation_1215 == 4294967295)
# ------
# Implies(Not(True), Observation_1216 == 4294967295)
# ------
# Implies(Not(True), Observation_1217 == 4294967295)
# ------
# Implies(Not(True), Observation_1218 == 4294967295)
# ------
# Implies(Not(True), Observation_1219 == 4294967295)
# ------
# Implies(Not(True), Observation_1220 == 4294967295)
# ------
# Implies(Not(True), Observation_1221 == 4294967295)
# ------
# Implies(Not(True), Observation_1222 == 4294967295)
# ------
# Implies(Not(True), Observation_1223 == 4294967295)
# ------
# Implies(Not(True), Observation_1224 == 4294967295)
# ------
# Implies(Not(True), Observation_1225 == 4294967295)
# ------
# Implies(Not(True), Observation_1226 == 4294967295)
# ------
# Implies(Not(True), Observation_1227 == 4294967295)
# ------
# Implies(Not(True), Observation_1228 == 4294967295)

# %%
solver.check()
# Out:
# sat

# %%
solver.reset()

solver.add(constraints)
solver.add(o != 7168)
solver.check()

# m = solver.model()
# list_of_var_set = [get_vars(a) for a in constraints]

# list_of_vars = set().union(*list_of_var_set)

# list_of_obsvs = [v for v in list_of_vars if str(v).startswith("Observation_")]
# # list_of_obsvs = [v for v in list_of_vars if str(v).startswith("function#return_value!0#1")]

# o = [o for o in list_of_obsvs if str(o) == "Observation_2"][0]
# m.evaluate(o)

# %%
list_of_var_set = [get_vars(a) for a in constraints]

list_of_vars = set().union(*list_of_var_set)

list_of_obsvs = [v for v in list_of_vars if str(v).startswith("Observation_")]
# list_of_obsvs = [v for v in list_of_vars if str(v).startswith("function#return_value!0#1")]

list_of_obsvs

# %%
len(list_of_obsvs)

# %%
def transitively_select_constraints(constraints, interested_vars):

    def intersection(s0, s1):
        result = set()
        for o0 in s0:
            for o1 in s1:
                if o0.get_id() == o1.get_id():
                    result.add(o0)
        return result

    interested_vars = list_of_obsvs
    constraints = constraints_back

    new_added = True
    transitively_included_vars = set()
    transitively_included_vars.update(list_of_obsvs)
    transitively_included_constraints = set()

    constraints = set(constraints)
    constraint_var_map = {}

    # get variables used in each constraints
    for constraint in constraints:
        constraint_var_map[constraint] = get_vars(constraint)

    while new_added:
        constraints_to_add = []
        for constraint in constraints:
            if intersection(constraint_var_map[constraint], transitively_included_vars):
                constraints_to_add.append(constraint)
        new_added = False 
        for constraint in constraints_to_add:
            transitively_included_vars.update(constraint_var_map[constraint])
            transitively_included_constraints.add(constraint)
            constraints.remove(constraint)
            new_added = True
    print(transitively_included_vars)
    print(transitively_included_constraints)
    return transitively_included_constraints

selected_constraints = transitively_select_constraints(constraints, list_of_obsvs)

# %%
len(selected_constraints)

# %%
t = Then('simplify', 'bit-blast', 'tseitin-cnf')
g = Goal()
g.add(constraints)

bitmap = {}
for ob in list_of_obsvs:
    for i in range(ob.size()):
        bitmap[(ob, i)] = Bool(str(ob)+str(i))
        mask = BitVecSort(ob.size()).cast(math.pow(2, i))
        g.add(bitmap[(ob, i)] == ((ob & mask) == mask))
        
sg = t(g)
# print(sg[0])
cnf_str = generate_cnf(sg[0], list_of_obsvs)
cnf_str
# def equality_substitution(old_goal, new_goal):
#     e = old_goal.as_expr()
#     old_constraints = [e.arg(i) for i in range(e.num_args())]
#     equality_constraints = [c for c in old_constraints if (not is_or(c)) and c.num_args() != 1]
#     subs = []
#     for cons in equality_constraints:
# #         print(cons)
#         assert(cons.num_args() == 0 or is_eq(cons))
#         if is_eq(cons):
#             subs.append((cons.arg(0), cons.arg(1)))
#     print(subs)
#     for cons in old_constraints:
#         new_goal.add(substitute(cons, subs))
        
# # Remove equality of arrays, which can be generated from memcpy
# new_goal = Goal()
# equality_substitution(sg[0], new_goal)
# sim_sg = Tactic('simplify')(new_goal)
# cnf_str = generate_cnf(sim_sg[0], list_of_obsvs)

# %%
with open("/home/cream/toy/toy.smt", "w") as f:
    f.write(cnf_str)
