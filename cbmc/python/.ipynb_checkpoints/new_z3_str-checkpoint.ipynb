# %%
from z3 import *

# %%
config_dir = "/home/ubuntu/src/lif/llvm/bench/meng/applied-crypto/des/"
smt2_path = config_dir + "cbmc.smt2"

# %%
# Wrapper for allowing Z3 ASTs to be stored into Python Hashtables. 
class AstRefKey:
    def __init__(self, n):
        self.n = n
    def __hash__(self):
        return self.n.hash()
    def __eq__(self, other):
        return self.n.eq(other.n)
    def __repr__(self):
        return str(self.n)

def askey(n):
    assert isinstance(n, AstRef)
    return AstRefKey(n)

def get_vars(f):
    r = set()
    def collect(f):
      if is_const(f): 
          if f.decl().kind() == Z3_OP_UNINTERPRETED and not askey(f) in r:
              r.add(askey(f))
      else:
          for c in f.children():
              collect(c)
    collect(f)
    return {ele.n for ele in r}

def get_var_str(f):
    r = set()
    def collect(f):
      if is_const(f): 
          if f.decl().kind() == Z3_OP_UNINTERPRETED and not askey(f) in r:
              r.add(askey(f))
      else:
          for c in f.children():
              collect(c)
    collect(f)
    return {"|{}|".format(str(ele.n)) for ele in r}

import re
# either a declaration, definition, lhs equality that contains var
# if none of the above, then any constraint that contains var
def is_important_constraint(constraint, var):
    if "__CPROVER_deallocated" in constraint and var in constraint:
        # we want to preserve safe-pointer constraint
        return True
    pattern = "(\(assert \(= |\(define-fun |\(declare-fun |\(assert \(= \(select )(\|.*?\|)"
    matches = re.match(pattern, constraint)
    if matches:
        if matches.group(2) == var:
            return True
        else:
            return False
    else:
        return var in constraint

def get_var_in_script(script):
    pattern = "\|.*?\||array\.\\d*"
    matches = re.findall(pattern, script)
    return set(matches)

# %%
def get_split_smt2_script(smt2_path):
    script = open(smt2_path).readlines()
    script = [line for line in script if not(line.startswith(("\n", ";")))]
    for i,line in enumerate(script):
        if "Observation_0" in line:
            break
    cbmc_smt2_script = script[:i]
    obsv_smt2_script = script[i:]

    # clean up cbmc script, specifically, remove definition of predicate that's not needed
    safe_pointer_predicate_vars = []
    for line in cbmc_smt2_script:
        pattern = "\(assert (\|B\d*\|)\)"
        matches = re.findall(pattern, line)
        safe_pointer_predicate_vars.extend(matches)

    def is_needed(line):
        if "set-" in line:
            return False
        if "define-fun" not in line:
            return True
        return any(pred in line for pred in safe_pointer_predicate_vars)
    cbmc_smt2_script = [line for line in cbmc_smt2_script if is_needed(line)]

    # deduplicate
    cbmc_smt2_script = list(dict.fromkeys(cbmc_smt2_script))
    return cbmc_smt2_script, obsv_smt2_script

cbmc_smt2_script, obsv_smt2_script = get_split_smt2_script(smt2_path)

# %%
def get_sliced_obsv_script(var_strs, obsv_smt2_script):
    sliced_script = []
    for line in obsv_smt2_script[::-1]:
        if any(v in line for v in var_strs):
            sliced_script = [line] + sliced_script
    return sliced_script

sliced_obsv_script = get_sliced_obsv_script(["Observation_12921"], obsv_smt2_script)
obsv_dep_vars = get_var_in_script("".join(sliced_obsv_script))

# %%
def get_sliced_cbmc_script(var_strs, cbmc_smt2_script):
    dep_vars = set(var_strs)
    sliced_script = []
    for line in cbmc_smt2_script[::-1]:
        if line.startswith(("(declare-fun", "(define-fun")):
            line_var_name = line.split(" ")[1]
            if any(v == line_var_name for v in dep_vars):
                sliced_script = [line] + sliced_script
        elif line.startswith("(assert (="):
            lhs = line.split(" ")[2]
            if (lhs in dep_vars):
                dep_vars |= get_var_in_script(line)
                sliced_script = [line] + sliced_script
        elif line.startswith("(assert"):
            if any(v in line for v in dep_vars):
                sliced_script = [line] + sliced_script
        else:
            print(line)
            assert(False)
    return sliced_script

# sliced_cbmc_script = get_sliced_cbmc_script(obsv_dep_vars, cbmc_smt2_script)
# get_sliced_cbmc_script(new_obsv_dep_vars, cbmc_smt2_script)

# %%
def compute_id_to_offset(all_models):
    # compute base and offset for each model
    object_id_to_offsets = {}
    object_gap = 1048576
    for val in all_models:
        object_id = val // object_gap
        if object_id not in object_id_to_offsets:
            object_id_to_offsets[object_id] = []
        object_id_to_offsets[object_id].append(val % object_gap)
    return object_id_to_offsets

def enumerate_memeory_location_for_obsv(obsv_str, cbmc_smt2_script, obsv_smt2_script):
    solver = Solver(ctx=Context())

    sliced_obsv_script = get_sliced_obsv_script([obsv_str], obsv_smt2_script)
    obsv_dep_vars = get_var_in_script("".join(sliced_obsv_script))
    sliced_cbmc_script = get_sliced_cbmc_script(obsv_dep_vars, cbmc_smt2_script)

    constraints = parse_smt2_string("".join(sliced_cbmc_script + sliced_obsv_script), ctx=solver.ctx)

    # get obsv variable for use in enumeration
    for c in constraints[::-1]:
        for v in get_vars(c):
            if str(v) == obsv_str.strip("|"):
                obsv_var = v
                break

    solver.set("timeout", 3*1000)
    solver.add(constraints)
    # enumerate the model
    z3_timeout = False
    all_models = []
    for i in range(1000):
        solver_result = solver.check()
        if (solver_result == sat):
            m = solver.model()
            all_models.append(m[obsv_var].as_signed_long())
            solver.add(obsv_var != m[obsv_var])
        elif (solver_result == unknown):
            print("Z3 timeout on original constraint {}".format(obsv_str), flush=True)
            z3_timeout = True
            break
        else:
            break
    if i == 999:
        print("Error: the number of models is too large {}".format(obsv_str), flush=True)
        assert(False)

    
    if not z3_timeout:
        return (len(all_models), compute_id_to_offset(all_models))

    ########################################
    # If z3 timeouts, we relaxed the constraint by removing the premise
    ########################################
    print("Retry by relax premise {}".format(obsv_str))

    # HACK: the last few constraints are obsv constraints
    obsv_constraints = []
    for c in constraints[::-1]:
        if is_implies(c):
            obsv_constraints.append(c)
        else:
            break
    print(obsv_constraints)
    # extract conclusions and OR together
    conclusions = [c.children()[1] for c in obsv_constraints]
    new_obsv_dep_vars = set().union(*[get_var_str(c) for c in conclusions])
    new_sliced_cbmc_script = get_sliced_cbmc_script(new_obsv_dep_vars, cbmc_smt2_script)
    new_cbmc_constraints = parse_smt2_string("".join(new_sliced_cbmc_script), ctx=solver.ctx)
    solver.reset()
    solver.set("timeout", 3*1000)
    solver.add([Or(conclusions)] + list(new_cbmc_constraints))

    # enumerate the model
    failed = False
    all_models = []
    for i in range(1000):
        solver_result = solver.check()
        if (solver_result == sat):
            m = solver.model()
            all_models.append(m[obsv_var].as_signed_long())
            solver.add(obsv_var != m[obsv_var])
        elif (solver_result == unknown):
            print("ERROR: Z3 timeout on relaxed constraint {}".format(obsv_str), flush=True)
            failed = True
        else:
            break
    if i == 999:
        print("Error: the number of models is too large {}".format(obsv_str), flush=True)
        failed = True
        
    if not failed:
        return (len(all_models), compute_id_to_offset(all_models))
        
    ########################################
    # If z3 still timeouts or number of model exceed upper limit, we relaxed the constraint by freeing offset variable
    ########################################
    print("Retry by relax offset variable {}".format(obsv_str))
    


    return (len(all_models), compute_id_to_offset(all_models))


# enumerate_memeory_location_for_obsv("|Observation_12921|", cbmc_smt2_script, obsv_smt2_script)
enumerate_memeory_location_for_obsv("|Observation_20462|", cbmc_smt2_script, obsv_smt2_script)
# Out:
# Z3 timeout on original constraint |Observation_20462|
# Retry by relax constraint |Observation_20462|
# [Implies(True,
#         Observation_20462 ==
#         cbmc_pointer_object_24190!0@1#2*1048576 +
#         cbmc_pointer_offset_24190!0@1#2)]
# ERROR: Z3 timeout on relaxed constraint |Observation_20462|
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_121397/1904299800.py in <module>
#      94
#      95 # enumerate_memeory_location_for_obsv("|Observation_12921|", cbmc_smt2_script, obsv_smt2_script)
# ---> 96 enumerate_memeory_location_for_obsv("|Observation_20462|", cbmc_smt2_script, obsv_smt2_script)
#
# /tmp/ipykernel_121397/1904299800.py in enumerate_memeory_location_for_obsv(obsv_str, cbmc_smt2_script, obsv_smt2_script)
#      83         elif (solver_result == unknown):
#      84             print("ERROR: Z3 timeout on relaxed constraint {}".format(obsv_str), flush=True)
# ---> 85             assert(False)
#      86         else:
#      87             break
#
# AssertionError:

# %%
list_of_vars = get_var_in_script("".join(obsv_smt2_script))
obsv_vars = [o for o in list_of_vars if "Observation_" in o]
obsv_vars.sort(key=lambda x: int(x.strip("|").split("_")[-1].split("!")[0]))
len(obsv_vars)
# Out:
# 21172

# %%
from joblib import Parallel, delayed
import copy, random


def wrapper(chunk, cbmc_pairs, obsv_pairs):
    result = []
    for o in chunk:
        print("Processing {}".format(o))
        result.append((o, enumerate_memeory_location_for_obsv(o, cbmc_pairs, obsv_pairs)))
        print("Done {}".format(o))
    return result

n_jobs = 30
chunk_size = len(obsv_vars) // (n_jobs-1)
random.shuffle(obsv_vars)
chunks = output=[obsv_vars[i:i + chunk_size] for i in range(0, len(obsv_vars), chunk_size)]
chunk_result = Parallel(n_jobs=n_jobs, backend="loky")(delayed(wrapper)(chunk, cbmc_smt2_script, obsv_smt2_script) for chunk in chunks)
infos = dict(sum(chunk_result, []))
# Out:
# Processing |Observation_3023|
# Done |Observation_3023|
# Processing |Observation_10185|
# Done |Observation_10185|
# Processing |Observation_5708|
# Done |Observation_5708|
# Processing |Observation_11673|
# Done |Observation_11673|
# Processing |Observation_3737|
# Done |Observation_3737|
# Processing |Observation_590|
# Done |Observation_590|
# Processing |Observation_2952|
# Done |Observation_2952|
# Processing |Observation_565|
# Done |Observation_565|
# Processing |Observation_16512|
# Done |Observation_16512|
# Done |Observation_641|
# Processing |Observation_6122|
# Done |Observation_6122|
# Processing |Observation_17297|
# Done |Observation_17297|
# Processing |Observation_11240|
# Done |Observation_11240|
# Processing |Observation_16755|
# Done |Observation_16755|
# Processing |Observation_7641|
# Done |Observation_7641|
# Processing |Observation_5143|
# Done |Observation_5143|
# Processing |Observation_11913|
# Done |Observation_11913|
# Processing |Observation_1802|
# Done |Observation_1802|
# Processing |Observation_4781|
# Done |Observation_4781|
# Processing |Observation_10516|
# Done |Observation_10516|
# Processing |Observation_10897|
# Done |Observation_10897|
# Processing |Observation_3731|
# Done |Observation_3731|
# Processing |Observation_4930|
# Done |Observation_4930|
# Processing |Observation_21160|
# Done |Observation_21160|
# Processing |Observation_16414|
# Done |Observation_16414|
# Processing |Observation_4381|
# Done |Observation_4381|
# Processing |Observation_20648|
# Done |Observation_20648|
# Processing |Observation_19177|
# Done |Observation_19177|
# Processing |Observation_18671|
# Done |Observation_18671|
# Processing |Observation_7375|
# Done |Observation_7375|
# Processing |Observation_18675|
# Done |Observation_18675|
# Processing |Observation_18453|
# Done |Observation_18453|
# Processing |Observation_13985|
# Done |Observation_13985|
# Processing |Observation_2140|
# Done |Observation_2140|
# Processing |Observation_10014|
# Done |Observation_10014|
# Processing |Observation_1354|
# Done |Observation_1354|
# Processing |Observation_9556|
# Done |Observation_9556|
# Processing |Observation_14312|
# Done |Observation_14312|
# Processing |Observation_9636|
# Done |Observation_9636|
# Processing |Observation_1130|
# Done |Observation_1130|
# Processing |Observation_9945|
# Done |Observation_9945|
# Processing |Observation_256|
# Done |Observation_256|
# Processing |Observation_19633|
# Done |Observation_19633|
# Processing |Observation_13828|
# Done |Observation_13828|
# Processing |Observation_12969|
# Done |Observation_12969|
# Processing |Observation_19013|
# Done |Observation_19013|
# Processing |Observation_11158|
# Done |Observation_11158|
# Processing |Observation_20725|
# Done |Observation_20725|
# Processing |Observation_6628|
# Done |Observation_6628|
# Processing |Observation_15804|
# Done |Observation_15804|
# Processing |Observation_18564|
# Done |Observation_18564|
# Processing |Observation_3005|
# Done |Observation_3005|
# Processing |Observation_15223|
# Done |Observation_15223|
# Processing |Observation_7382|
# Done |Observation_7382|
# Processing |Observation_11672|
# Done |Observation_11672|
# Processing |Observation_4530|
# Done |Observation_4530|
# Processing |Observation_1252|
# Done |Observation_1252|
# Processing |Observation_19468|
# Done |Observation_19468|
# Processing |Observation_20987|
# Done |Observation_20987|
# Processing |Observation_10077|
# Done |Observation_10077|
# Processing |Observation_5364|
# Done |Observation_5364|
# Processing |Observation_11517|
# Done |Observation_11517|
# Processing |Observation_14798|
# Done |Observation_14798|
# Processing |Observation_14094|
# Done |Observation_14094|
# Processing |Observation_15731|
# Done |Observation_15731|
# Processing |Observation_19047|
# Done |Observation_19047|
# Processing |Observation_20406|
# Done |Observation_20406|
# Processing |Observation_7875|
# Done |Observation_7875|
# Processing |Observation_12733|
# Done |Observation_12733|
# Processing |Observation_12116|
# Done |Observation_12116|
# Done |Observation_9335|
# Processing |Observation_16777|
# Done |Observation_16777|
# Processing |Observation_18356|
# Done |Observation_18356|
# Processing |Observation_3085|
# Done |Observation_3085|
# Processing |Observation_9625|
# Done |Observation_9625|
# Processing |Observation_934|
# Done |Observation_934|
# Processing |Observation_16132|
# Done |Observation_16132|
# Processing |Observation_18812|
# Done |Observation_18812|
# Processing |Observation_2617|
# Done |Observation_2617|
# Processing |Observation_1047|
# Done |Observation_1047|
# Processing |Observation_5613|
# Done |Observation_5613|
# Processing |Observation_19597|
# Done |Observation_19597|
# Processing |Observation_15171|
# Done |Observation_15171|
# Processing |Observation_14235|
# Done |Observation_14235|
# Processing |Observation_17710|
# Done |Observation_17710|
# Processing |Observation_10482|
# Done |Observation_10482|
# Processing |Observation_18085|
# Done |Observation_18085|
# Processing |Observation_3904|
# Done |Observation_3904|
# Processing |Observation_19982|
# Done |Observation_19982|
# Processing |Observation_8631|
# Done |Observation_8631|
# Processing |Observation_17360|
# Done |Observation_17360|
# Processing |Observation_15585|
# Done |Observation_15585|
# Processing |Observation_18170|
# Done |Observation_18170|
# Processing |Observation_20828|
# Done |Observation_20828|
# Processing |Observation_6751|
# Done |Observation_6751|
# Processing |Observation_233|
# Done |Observation_233|
# Processing |Observation_17375|
# Done |Observation_17375|
# Processing |Observation_6724|
# Done |Observation_6724|
# Processing |Observation_8670|
# Done |Observation_8670|
# Processing |Observation_4925|
# Done |Observation_4925|
# Processing |Observation_6354|
# Done |Observation_6354|
# Processing |Observation_4687|
# Done |Observation_4687|
# Processing |Observation_8889|
# Done |Observation_8889|
# Processing |Observation_9376|
# Done |Observation_9376|
# Processing |Observation_15036|
# Done |Observation_15036|
# Processing |Observation_15507|
# Done |Observation_15507|
# Processing |Observation_6434|
# Done |Observation_6434|
# Processing |Observation_19087|
# Done |Observation_19087|
# Processing |Observation_2265|
# Done |Observation_2265|
# Processing |Observation_12029|
# Done |Observation_12029|
# Processing |Observation_13015|
# Done |Observation_13015|
# Processing |Observation_15230|
# Done |Observation_15230|
# Processing |Observation_6472|
# Done |Observation_6472|
# Processing |Observation_21155|
# Done |Observation_21155|
# Processing |Observation_3686|
# Done |Observation_3686|
# Processing |Observation_18776|
# Done |Observation_18776|
# Processing |Observation_10432|
# Done |Observation_10432|
# Processing |Observation_10198|
# Done |Observation_10198|
# Processing |Observation_240|
# Done |Observation_240|
# Processing |Observation_13717|
# Done |Observation_13717|
# Processing |Observation_6011|
# Done |Observation_6011|
# Processing |Observation_20476|
# Done |Observation_20476|
# Processing |Observation_2014|
# Done |Observation_2014|
# Processing |Observation_16876|
# Done |Observation_16876|
# Processing |Observation_3319|
# Done |Observation_3319|
# Processing |Observation_4018|
# Done |Observation_4018|
# Processing |Observation_17926|
# Done |Observation_17926|
# Processing |Observation_16505|
# Done |Observation_16505|
# Processing |Observation_16599|
# Done |Observation_16599|
# Processing |Observation_12777|
# Done |Observation_12777|
# Processing |Observation_20370|
# Done |Observation_20370|
# Processing |Observation_973|
# Done |Observation_973|
# Processing |Observation_683|
# Done |Observation_683|
# Processing |Observation_11201|
# Done |Observation_11201|
# Processing |Observation_10915|
# Done |Observation_10915|
# Processing |Observation_7895|
# Done |Observation_7895|
# Processing |Observation_14819|
# Done |Observation_14819|
# Processing |Observation_18662|
# Done |Observation_18662|
# Processing |Observation_2988|
# Done |Observation_2988|
# Processing |Observation_2965|
# Done |Observation_2965|
# Processing |Observation_3983|
# Done |Observation_3983|
# Processing |Observation_18098|
# Done |Observation_18098|
# Processing |Observation_12824|
# Done |Observation_12824|
# Processing |Observation_20819|
# Done |Observation_20819|
# Processing |Observation_2153|
# Done |Observation_2153|
# Processing |Observation_9372|
# Done |Observation_9372|
# Processing |Observation_16727|
# Done |Observation_16727|
# Processing |Observation_19564|
# Done |Observation_19564|
# Processing |Observation_12871|
# Done |Observation_12871|
# Processing |Observation_17287|
# Done |Observation_17287|
# Processing |Observation_5466|
# Done |Observation_5466|
# Processing |Observation_13256|
# Done |Observation_13256|
# Processing |Observation_1868|
# Done |Observation_1868|
# Processing |Observation_18827|
# Done |Observation_18827|
# Processing |Observation_5425|
# Done |Observation_5425|
# Processing |Observation_20824|
# Done |Observation_20824|
# Processing |Observation_18110|
# Done |Observation_18110|
# Processing |Observation_1786|
# Done |Observation_1786|
# Processing |Observation_4811|
# Done |Observation_4811|
# Processing |Observation_2310|
# Done |Observation_2310|
# Processing |Observation_15992|
# Done |Observation_15992|
# Processing |Observation_6806|
# Done |Observation_6806|
# Processing |Observation_20578|
# Z3 timeout on original constraint |Observation_20578|
# Retry by relax constraint |Observation_20869|
# ERROR: Z3 timeout on relaxed constraint |Observation_20869|
# Processing |Observation_8223|
# Done |Observation_8223|
# Processing |Observation_14104|
# Done |Observation_14104|
# Processing |Observation_6865|
# Done |Observation_6865|
# Processing |Observation_3595|
# Done |Observation_3595|
# Processing |Observation_1712|
# Done |Observation_1712|
# Processing |Observation_1315|
# Done |Observation_1315|
# Processing |Observation_3867|
# Done |Observation_3867|
# Processing |Observation_3293|
# Done |Observation_3293|
# Processing |Observation_14772|
# Done |Observation_14772|
# Processing |Observation_16485|
# Done |Observation_16485|
# Processing |Observation_6807|
# Done |Observation_6807|
# Processing |Observation_3710|
# Done |Observation_3710|
# Processing |Observation_14827|
# Done |Observation_14827|
# Processing |Observation_1663|
# Done |Observation_1663|
# Processing |Observation_3288|
# Done |Observation_3288|
# Processing |Observation_19855|
# Done |Observation_19855|
# Processing |Observation_457|
# Done |Observation_457|
# Processing |Observation_461|
# Done |Observation_461|
# Processing |Observation_4388|
# Done |Observation_4388|
# Processing |Observation_16825|
# Done |Observation_16825|
# Processing |Observation_2633|
# Done |Observation_2633|
# Processing |Observation_290|
# Done |Observation_290|
# Processing |Observation_8507|
# Done |Observation_8507|
# Processing |Observation_7835|
# Done |Observation_7835|
# Processing |Observation_8120|
# Done |Observation_8120|
# Processing |Observation_3964|
# Done |Observation_3964|
# Processing |Observation_5216|
# Done |Observation_5216|
# Processing |Observation_353|
# Done |Observation_353|
# Processing |Observation_12432|
# Done |Observation_12432|
# Processing |Observation_710|
# Done |Observation_710|
# Processing |Observation_3656|
# Done |Observation_3656|
# Processing |Observation_489|
# Done |Observation_489|
# Processing |Observation_7576|
# Done |Observation_7576|
# Processing |Observation_16425|
# Done |Observation_16425|
# Processing |Observation_16061|
# Done |Observation_16061|
# Processing |Observation_913|
# Done |Observation_913|
# Processing |Observation_9842|
# Done |Observation_9842|
# Processing |Observation_8447|
# Done |Observation_8447|
# Processing |Observation_9914|
# Done |Observation_9914|
# Processing |Observation_14488|
# Done |Observation_14488|
# Processing |Observation_3128|
# Done |Observation_3128|
# Processing |Observation_15603|
# Done |Observation_15603|
# Processing |Observation_16935|
# Done |Observation_16935|
# Processing |Observation_18825|
# Done |Observation_18825|
# Processing |Observation_12370|
# Done |Observation_12370|
# Processing |Observation_12342|
# Done |Observation_12342|
# Processing |Observation_4710|
# Done |Observation_4710|
# Processing |Observation_8193|
# Done |Observation_8193|
# Processing |Observation_20292|
# Done |Observation_20292|
# Processing |Observation_15796|
# Done |Observation_15796|
# Processing |Observation_15881|
# Done |Observation_15881|
# Processing |Observation_17167|
# Done |Observation_17167|
# Processing |Observation_15430|
# Done |Observation_15430|
# Processing |Observation_6765|
# Done |Observation_6765|
# Processing |Observation_8706|
# Done |Observation_8706|
# Processing |Observation_3663|
# Done |Observation_3663|
# Processing |Observation_17941|
# Done |Observation_17941|
# Processing |Observation_14834|
# Done |Observation_14834|
# Processing |Observation_19369|
# Done |Observation_19369|
# Processing |Observation_9426|
# Done |Observation_9426|
# Processing |Observation_2713|
# Done |Observation_2713|
# Processing |Observation_19075|
# Done |Observation_19075|
# Processing |Observation_681|
# Done |Observation_681|
# Processing |Observation_17478|
# Done |Observation_17478|
# Processing |Observation_19996|
# Done |Observation_19996|
# Processing |Observation_5969|
# Done |Observation_5969|
# Processing |Observation_19285|
# Done |Observation_19285|
# Processing |Observation_13322|
# Done |Observation_13322|
# Processing |Observation_15582|
# Done |Observation_15582|
# Processing |Observation_14878|
# Done |Observation_14878|
# Processing |Observation_11697|
# Done |Observation_11697|
# Processing |Observation_8182|
# Done |Observation_8182|
# Processing |Observation_3456|
# Done |Observation_3456|
# Processing |Observation_359|
# Done |Observation_359|
# Processing |Observation_12575|
# Done |Observation_12575|
# Processing |Observation_7623|
# Done |Observation_7623|
# Processing |Observation_8731|
# Done |Observation_8731|
# Processing |Observation_16040|
# Done |Observation_16040|
# Processing |Observation_13077|
# Done |Observation_13077|
# Processing |Observation_4076|
# Done |Observation_4076|
# Processing |Observation_17550|
# Done |Observation_17550|
# Processing |Observation_16575|
# Done |Observation_16575|
# Processing |Observation_3233|
# Done |Observation_3233|
# Processing |Observation_5975|
# Done |Observation_5975|
# Processing |Observation_14852|
# Done |Observation_14852|
# Processing |Observation_3697|
# Done |Observation_3697|
# Processing |Observation_12578|
# Done |Observation_12578|
# Processing |Observation_18393|
# Done |Observation_18393|
# Processing |Observation_8654|
# Done |Observation_8654|
# Processing |Observation_19555|
# Done |Observation_19555|
# Processing |Observation_9920|
# Done |Observation_9920|
# Processing |Observation_13689|
# Done |Observation_13689|
# Processing |Observation_11959|
# Done |Observation_11959|
# Processing |Observation_13607|
# Done |Observation_13607|
# Processing |Observation_15810|
# Done |Observation_15810|
# Processing |Observation_19920|
# Done |Observation_19920|
# Processing |Observation_12249|
# Done |Observation_12249|
# Processing |Observation_19270|
# Done |Observation_19270|
# Processing |Observation_3972|
# Done |Observation_3972|
# Processing |Observation_3046|
# Done |Observation_3046|
# Processing |Observation_8606|
# Done |Observation_8606|
# Processing |Observation_20097|
# Done |Observation_20097|
# Processing |Observation_15551|
# Done |Observation_15551|
# Processing |Observation_990|
# Done |Observation_990|
# Processing |Observation_1618|
# Done |Observation_1618|
# Processing |Observation_3266|
# Done |Observation_3266|
# Processing |Observation_14657|
# Done |Observation_14657|
# Processing |Observation_15891|
# Done |Observation_15891|
# Processing |Observation_18761|
# Done |Observation_18761|
# Processing |Observation_9887|
# Done |Observation_9887|
# Processing |Observation_1995|
# Done |Observation_1995|
# Processing |Observation_6831|
# Done |Observation_6831|
# Processing |Observation_9996|
# Done |Observation_9996|
# Processing |Observation_16501|
# Done |Observation_16501|
# Processing |Observation_9189|
# Done |Observation_9189|
# Processing |Observation_5839|
# Done |Observation_5839|
# Processing |Observation_13592|
# Done |Observation_13592|
# Processing |Observation_5391|
# Done |Observation_5391|
# Processing |Observation_11183|
# Done |Observation_11183|
# Processing |Observation_4649|
# Done |Observation_4649|
# Processing |Observation_17807|
# Done |Observation_17807|
# Processing |Observation_3291|
# Done |Observation_3291|
# Processing |Observation_14133|
# Done |Observation_14133|
# Processing |Observation_11610|
# Done |Observation_11610|
# Processing |Observation_10781|
# Done |Observation_10781|
# Processing |Observation_14368|
# Done |Observation_14368|
# Processing |Observation_3090|
# Done |Observation_3090|
# Processing |Observation_1591|
# Done |Observation_1591|
# Processing |Observation_14621|
# Done |Observation_14621|
# Processing |Observation_8195|
# Done |Observation_8195|
# Processing |Observation_14805|
# Done |Observation_14805|
# Processing |Observation_17766|
# Done |Observation_17766|
# Processing |Observation_1747|
# Done |Observation_1747|
# Processing |Observation_15546|
# Done |Observation_15546|
# Processing |Observation_4549|
# Done |Observation_4549|
# Processing |Observation_13883|
# Done |Observation_13883|
# Processing |Observation_5656|
# Done |Observation_5656|
# Processing |Observation_7139|
# Done |Observation_7139|
# Processing |Observation_12238|
# Done |Observation_12238|
# Processing |Observation_19650|
# Done |Observation_19650|
# Processing |Observation_6803|
# Done |Observation_6803|
# Processing |Observation_12361|
# Done |Observation_12361|
# Processing |Observation_6619|
# Done |Observation_6619|
# Processing |Observation_653|
# Done |Observation_653|
# Processing |Observation_5426|
# Done |Observation_5426|
# Processing |Observation_2618|
# Done |Observation_2618|
# Processing |Observation_8366|
# Done |Observation_8366|
# Processing |Observation_1580|
# Done |Observation_1580|
# Processing |Observation_4169|
# Done |Observation_4169|
# Processing |Observation_21154|
# Retry by relax constraint |Observation_20710|
# ERROR: Z3 timeout on relaxed constraint |Observation_20710|
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 436, in _process_worker
#     r = call_item()
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 288, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/home/ubuntu/.local/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/tmp/ipykernel_121397/1924337069.py", line 9, in wrapper
#   File "/tmp/ipykernel_121397/606125728.py", line 85, in enumerate_memeory_location_for_obsv
# AssertionError
# """
#
# The above exception was the direct cause of the following exception:
#
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_121397/1924337069.py in <module>
#      15 random.shuffle(obsv_vars)
#      16 chunks = output=[obsv_vars[i:i + chunk_size] for i in range(0, len(obsv_vars), chunk_size)]
# ---> 17 chunk_result = Parallel(n_jobs=n_jobs, backend="loky")(delayed(wrapper)(chunk, cbmc_smt2_script, obsv_smt2_script) for chunk in chunks)
#      18 infos = dict(sum(chunk_result, []))
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# AssertionError:

# %%
def get_pointer_to_name_and_type_map():
    mapping = {}
    f = open(config_dir + "pointer_numbering.csv")
    for line in f.readlines():
        line = line.strip()
        splits = line.split(",")
        var_type = splits[0]
        full_var = splits[1]
        numbering = splits[2]
        #histogram::1::2::i!0@1
        #histogram$$1$$2$$1$$i
        #histogram$$1$$2$$1$$1$$t
        mapping[int(numbering)] = (full_var.split("::")[-1].split("!")[0], var_type)
    return mapping

def is_pointer_or_array(var_type):
    # return "*" in var_type or var_type.count('[') >= 2
    return var_type.count('[') >= 2

pointer_mapping = get_pointer_to_name_and_type_map()
ds_file = open(config_dir + "ds_of_obsvs.txt", "w")
for obsv, info in sorted(infos.items(), key=lambda o: int(o[0].strip("|").split("_")[1])):
    index = obsv.strip("|").split("_")[1]
    memory_locs = []
    ds_size = 0
    for (base, offsets) in info[1].items():
        if (base == -1):
            # decoy access is not part of ds
            continue
        var_name = pointer_mapping[base][0]
        var_type = pointer_mapping[base][1]
        for offset in offsets:
            memory_locs.append("((char*){}{})+{}".format("" if is_pointer_or_array(var_type) else "&", var_name, offset))
            ds_size += 1
    memory_locs = ",".join(memory_locs)
    memory_locs = "{"+memory_locs+"}"
    ds_file.write("#define ds_{} (void* [{}]){}\n".format(index, ds_size, memory_locs))
    ds_file.write("#define ds_size_{} {}\n".format(index, ds_size))
ds_file.write("#define ds_nil (void* []){}\n")
ds_file.write("#define ds_size_nil 0\n")
ds_file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_121397/608411291.py in <module>
#      20 pointer_mapping = get_pointer_to_name_and_type_map()
#      21 ds_file = open(config_dir + "ds_of_obsvs.txt", "w")
# ---> 22 for obsv, info in sorted(infos.items(), key=lambda o: int(o[0].strip("|").split("_")[1])):
#      23     index = obsv.strip("|").split("_")[1]
#      24     memory_locs = []
#
# NameError: name 'infos' is not defined
